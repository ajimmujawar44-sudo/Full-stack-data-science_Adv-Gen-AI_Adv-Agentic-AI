# %%
Syntax:

# %%
Python
variable_name = value

# %% [markdown]
# # Example 1: Integer variable

# %%
age=25      # Here, 'age' is a variable, and it stores an integer value 25
print(age)  # we get output: 25
# Out:
# 25

# %% [markdown]
# # Example 2: String Variable

# %%
name ="Ajim"  #'name' is s variable,storing a string "ajim"
print(name)   # output: Ajim
# Out:
# Ajim

# %% [markdown]
# # Example 3: Float Variable

# %%
price = 19.99  # 'price' is a variable, storing a floating-point number
print(price)   #output: 19.99
# Out:
# 19.99

# %% [markdown]
# # Example 4: Boolen Variable

# %%
is_active = True   #'is a variable,storing a Boolean value
print(is_active)   # output: True
# Out:
# True

# %% [markdown]
# 1.storing and Printing a Value

# %%
#storing the value 10 in a variable called 'x'
x=10
# printing the value of 'x'
print(x)   #Output: 10
# Out:
# 10

# %% [markdown]
# 2.Using Variable in Expression

# %%
python

# %%
# Assigning value to variable
a=5
b=3
# Adding two variable and storing the result in 'result'
result = a + b
# Printing the result
print(result)   #Output: 8
# Out:
# 8

# %% [markdown]
# 3.Changing the Value of a Variable

# %%
python

# %%
# Initial value
score = 50
print(score)   #Output: 'score'
# Out:
# 50

# %%
# Changing the value of 'score'
score= 100
print(score)   #Output: 100
# Out:
# 100

# %% [markdown]
# 4.Concatenating String

# %%
python

# %%
#Assigning value tovariable
length = 10
width = 5

# Calulating the area of a rectangle
area = length * width
print(area)    #Output: 50
# Out:
# 50

# %%
Base = 12
Height = 20

area = Base*Height/(2) #area of a Tringle
print(area)            #Output: 120.0
# Out:
# 120.0

# %% [markdown]
#   Reassigning Value to Variable

# %%
Python allows you reassign to a new value at any time.
    python

# %%
x = 10    #Initial value of x
print(x)  # Output: 10
# Out:
# 10

# %%
# Reassigning the value of x
x = 44
print(x)    #Output: 44
# Out:
# 44

# %% [markdown]
# notes: Variable can store any tupe of data,including numbers,string,
#     dicitionaries,objects, etc.
