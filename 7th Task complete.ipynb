# %% [markdown]
# # TYPE CASTING

# %% [markdown]
# Test case 1

# %%
int(4)
# Out:
# 4

# %%
int(4.0)
# Out:
# 4

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(2+10j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(2+10j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('15')
# Out:
# 15

# %%
int('5.7')   # Changing data type from folat string to int is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('5.7')
#
# ValueError: invalid literal for int() with base 10: '5.7'

# %%
int(23.4,42.6)   # we can not pass more than one argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(23.4,42.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# # Test case 2

# %%
float(4)
# Out:
# 4.0

# %%
float(2.4)
# Out:
# 2.4

# %%
float(4+8j)    # changing data type from complex to float is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 float(4+8j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('6')
# Out:
# 6.0

# %%
float('6.6')
# Out:
# 6.6

# %%
float("1")
# Out:
# 1.0

# %%
float('2.1','5.6')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float('2.1','5.6')   #
#
# TypeError: float expected at most 1 argument, got 2

# %% [markdown]
# # Test case 3

# %%
bool(3)
# Out:
# True

# %%
bool(3.3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool('abcd')
# Out:
# True

# %%
bool('ab','cd')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 bool('ab','cd')
#
# TypeError: bool expected at most 1 argument, got 2

# %%
bool('12,'33')
# Out:
#   Cell In[25], line 1
#     bool('12,'33')
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Test case 4

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(1,9)
# Out:
# (1+9j)

# %%
complex(1.2,3.1)
# Out:
# (1.2+3.1j)

# %%
complex('abcd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 complex('abcd')
#
# ValueError: complex() arg is a malformed string

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,False)
# Out:
# 0j

# %%
complex('10','20')   # it can not take two string together
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # Test case

# %%
str(1)
# Out:
# '1'

# %%
str(2.2)
# Out:
# '2.2'

# %%
str('2.0')
# Out:
# '2.0'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(2,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 str(2,6)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
str('2','4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 str('2','4')
#
# TypeError: decoding str is not supported

# %% [markdown]
# # OPERATORS

# %% [markdown]
# Arthimatic operator

# %%
a=2
b=4

# %%
print(a)
print(b)
# Out:
# 2
# 4

# %%
print(a+b)   # Add
print(a-b)   # Sub
print(b-a)   
print(a*b)    # Multi
print(a**b)   # Squre
print(b/a)    # Division
print(b//a)   #  float division 
print(a%b)    # moudulas(percentage)
# Out:
# 6
# -2
# 2
# 8
# 16
# 2.0
# 2
# 2

# %%
print(a***b)   # Cube is not exist
# Out:
#   Cell In[52], line 1
#     print(a***b)   # Cube is not exist
#              ^
# SyntaxError: invalid syntax

# %%
print(a*3)
# Out:
# 6

# %% [markdown]
# # Assignment operator

# %%
a = 10
a
# Out:
# 10

# %%
a += 4
a
# Out:
# 21

# %%
a -=5
a
# Out:
# 16

# %%
a *=3
a
# Out:
# 48

# %%
a /=2
a
# Out:
# 24.0

# %%
a //=2
a
# Out:
# 6.0

# %% [markdown]
# # Relational operator

# %%
a = 5
b = 4

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# False
# True

# %% [markdown]
# # Logical operator

# %%
a=10
b=25

# %%
a<6 and b<3
# Out:
# False

# %%
a>6 and b>3
# Out:
# True

# %%
a<12 and b<45
# Out:
# True

# %%
a>12 and b>45
# Out:
# False
