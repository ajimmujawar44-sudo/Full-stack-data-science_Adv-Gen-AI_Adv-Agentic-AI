# %% [markdown]
# # Variable in Python

# %% [markdown]
# # Printing the values stored in the variables

# %%
first_name = 'Azim'
Last_name = 'mujawar'
Country = 'India'
State = 'Maharashtra'
Skill = 'FSDS adv genai and adv agenai'

print('first name:',first_name)
print('first name length:', len(first_name))
print('Last name:',Last_name)
print('Last name length:', len(Last_name))
print('Country:', Country)
print('State:', State)
print('Skill:', Skill)
# Out:
# first name: Azim
# first name length: 4
# Last name: mujawar
# Last name length: 7
# Country: India
# State: Maharashtra
# Skill: FSDS adv genai and adv agenai

# %% [markdown]
# # Declaring multiple variables in one line

# %%
first_name,last_name,country,married='Azim','Mujawar','India','is_unmarried'

print(first_name, last_name, country, married)
print('First name:',first_name)
print('Last name:',last_name)
# Out:
# Azim Mujawar India is_unmarried
# First name: Azim
# Last name: Mujawar
